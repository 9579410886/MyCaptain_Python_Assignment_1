# %%
#string method
string = "  My name is Pankaj Atram  "

x=string.capitalize()
print(x)
x=string.casefold()
print(x)
x= string.center(50 ,"0")
print(x)
x= string.count("is", 6, 10)
print(x)
x=string.encode()
print(x)
x= string.endswith("Pankaj")
print(x)
print(string.expandtabs(2))
x= string.find("is")
print(x)
x= string.index("is")
print(x)
x=string.isalnum()
print(x)
x=string.isalpha()
print(x)
x=string.isdecimal()
print(x)
x=string.isidentifier()
print(x)
x=string.islower()
print(x)
print(string.isupper())
print(string.isnumeric())
print(string.isprintable())
print(string.isspace())
print(string.istitle())
print(string.lstrip())
print(string.join("is"))
print(string.ljust(50,"0"))
print(string.lower())
print(string.upper())
print(string.rpartition("is"))
print(string.rsplit())
print(string.split())
x="si"
y="jk"
print(string.maketrans(x,y))
print(string.strip())
print(string.swapcase())
print(string.title())
print(string.startswith("  My"))
myDict={1: 2}
print(string.translate(myDict))
print(string.zfill(30))
# Out:
#   my name is pankaj atram
#   my name is pankaj atram
# 00000000000  My name is Pankaj Atram  000000000000
# 0
# b'  My name is Pankaj Atram  '
# False
#   My name is Pankaj Atram
# 10
# 10
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# My name is Pankaj Atram
# i  My name is Pankaj Atram  s
#   My name is Pankaj Atram  00000000000000000000000
#   my name is pankaj atram
#   MY NAME IS PANKAJ ATRAM
# ('  My name ', 'is', ' Pankaj Atram  ')
# ['My', 'name', 'is', 'Pankaj', 'Atram']
# ['My', 'name', 'is', 'Pankaj', 'Atram']
# {115: 106, 105: 107}
# My name is Pankaj Atram
#   mY NAME IS pANKAJ aTRAM
#   My Name Is Pankaj Atram
# True
#   My name is Pankaj Atram
# 000  My name is Pankaj Atram

# %%
# list Method

a=["AAA", 123, 2323, 4343, 'abcd']

a.append(5665)
print(a)
print(a.count("AAA"))
b=[]
b=a.copy()
print(b)
a.clear()
print(b.count(123))
print(b.index('abcd'))
b.reverse()
print(b)
b.pop()
print(b)
b.remove(123)
print(b)

a=[645,775,234,86]
a.sort()
print(a)

b=['Pankaj']
a.extend(b)
print(a)

a.insert(0,"My")
print(a)
# Out:
# ['AAA', 123, 2323, 4343, 'abcd', 5665]
# 1
# ['AAA', 123, 2323, 4343, 'abcd', 5665]
# 1
# 4
# [5665, 'abcd', 4343, 2323, 123, 'AAA']
# [5665, 'abcd', 4343, 2323, 123]
# [5665, 'abcd', 4343, 2323]
# [86, 234, 645, 775]
# [86, 234, 645, 775, 'Pankaj']
# ['My', 86, 234, 645, 775, 'Pankaj']
